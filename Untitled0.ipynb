# %%
print("hello")
# Out:
# hello

# %%
print("hell world "end="0")

print ("yash")
# Out:
#   File "<ipython-input-7-ddba065a892f>", line 1
#     print("hell world "end="0")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print ("hello",end="$")
print("yash")
print("ritik")
# Out:
# hello$yash
# ritik

# %%
x=10
print(x,type(x))
# Out:
# 10 <class 'int'>

# %%
x="10"
print(type(x))
# Out:
# <class 'str'>

# %%
address="""71indar colonay anbhsssvvvhv

 bani park"""
print(address)
# Out:
# 71indar colonay anbhsssvvvhv
#
#  bani park

# %%
#hey
#dsalf
'''
'''
# Out:
# '\n'

# %%
#string formating
#%d %s
year= 2015
company =("yash company")
print("year is", year , "company name is", company)
# Out:
# year is 2015 company name is yash company

# %%
print ( f"yearis {year} company name is {compamy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-5c090e8f46df> in <cell line: 1>()
# ----> 1 print ( f"yearis {year} company name is {compamy}")
#       2
#
# NameError: name 'compamy' is not defined

# %%
username ="regex"
msg =f"hey user {username}"
print (msg)
username ="aman"
print("aman")
# Out:
# hey user regex
# aman

# %%
state="RAJASTHAN"
state[-2]
# Out:
# 'A'

# %%
state="RAJASTHAN"
state[0:5]
# Out:
# 'RAJAS'

# %%
state="RAJASTHAN"
state[2:]
# Out:
# 'JASTHAN'

# %%
state="RAJASTHAN"
state[0:]
# Out:
# 'RAJASTHAN'

# %%
state="RAJASTHAN"
state[-2:]
# Out:
# 'AN'

# %%
state="RAJASTHAN"
state[5:]
# Out:
# 'THAN'

# %%
state="RAJASTHAN"
state[-1:-4:-1]
# Out:
# 'NAH'
